# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
# %matplotlib inline 
import seaborn as sns

# %% [markdown]
# - ABOVE WE IMPORTED ALL THE NECESSARY LIBRARIES FOR THE DATA ANAYALYSIS

# %%
df=pd.read_csv('Auto Sales data.csv')

# %% [markdown]
# - HERE WE RED THE DATA SETS VALUE INTO THE VARIABLE DF

# %%
df.head(10)
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10168               36      96.66                1  3479.76
# 5        10180               29      86.13                9  2497.77
# 6        10188               48     114.84                1  5512.32
# 7        10211               41     114.84               14  4708.44
# 8        10223               37     107.18                1  3965.66
# 9        10237               23     101.44                7  2333.12
#
#     ORDERDATE  DAYS_SINCE_LASTORDER   STATUS  PRODUCTLINE  MSRP PRODUCTCODE  \
# 0  24/02/2018                   828  Shipped  Motorcycles    95    S10_1678
# ...

# %% [markdown]
# - HERE WE DISPLAY THE FIRST 10 ELEMENTS OF THE DATA SET

# %%
df.tail(10)
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 2737        10293               32      60.06                1  1921.92
# 2738        10306               35      59.51                6  2082.85
# 2739        10315               40      55.69                5  2227.60
# 2740        10327               37      86.74                4  3209.38
# 2741        10337               42      97.16                5  4080.72
# 2742        10350               20     112.22               15  2244.40
# 2743        10373               29     137.19                1  3978.51
# 2744        10386               43     125.99                4  5417.57
# 2745        10397               34      62.24                1  2116.16
# 2746        10414               47      65.52                9  3079.44
#
#        ORDERDATE  DAYS_SINCE_LASTORDER    STATUS PRODUCTLINE  MSRP  \
# 2737  09/09/2019                  3003   Shipped       Ships    54
# ...

# %% [markdown]
# - HERE WE DISPLAY THE LAST 10 ELEMENTS OF THE DATA SET

# %%
df.describe()
# Out:
#         ORDERNUMBER  QUANTITYORDERED    PRICEEACH  ORDERLINENUMBER  \
# count   2747.000000      2747.000000  2747.000000      2747.000000
# mean   10259.761558        35.103021   101.098952         6.491081
# std       91.877521         9.762135    42.042549         4.230544
# min    10100.000000         6.000000    26.880000         1.000000
# 25%    10181.000000        27.000000    68.745000         3.000000
# 50%    10264.000000        35.000000    95.550000         6.000000
# 75%    10334.500000        43.000000   127.100000         9.000000
# max    10425.000000        97.000000   252.870000        18.000000
#
#               SALES  DAYS_SINCE_LASTORDER         MSRP
# count   2747.000000           2747.000000  2747.000000
# mean    3553.047583           1757.085912   100.691664
# std     1838.953901            819.280576    40.114802
# min      482.130000             42.000000    33.000000
# 25%     2204.350000           1077.000000    68.000000
# ...

# %% [markdown]
# - THE NUMBER OF ITEMS IN MY DATA SET IS 2747
# - THE MEAN OF ALL THE PRICES OF AUTOMOBILES IN MY DATA SET IS 101
# - THE MEAN DAYS SINCE LAST ORDER OF THE AUTOMOBILES IN MY DATA SET IS 1757
# - THE MEAN MSRP(It stands for Manufacturer's Suggested Retail Price and represents the suggested selling price for each item.)
#   IN MY DATA SET IS 100
# - THE MAXIMUM QUANTIY OF PRODUCTS ORDERED IN MY DATA SET IS 97
# - THE MINIMUM QUANTITY OF PRODUCTS ORDERED IN MY DATA SET IS 6
# - THE MINIMUM PRICE OF A PROCUCT IN MY DATA SET IS 26
# - THE MAXIUMUM PRICE OF A PRODUCT IN MY DATA SET IS 252
# - THE LOWEST SALES AMOUNT IN MY DATA SET IS 482
# - THE HIGHEST SALES AMOUNT IN MY DATA SET IS 14082

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2747 entries, 0 to 2746
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ORDERNUMBER           2747 non-null   int64
#  1   QUANTITYORDERED       2747 non-null   int64
#  2   PRICEEACH             2747 non-null   float64
#  3   ORDERLINENUMBER       2747 non-null   int64
#  4   SALES                 2747 non-null   float64
#  5   ORDERDATE             2747 non-null   object
#  6   DAYS_SINCE_LASTORDER  2747 non-null   int64
#  7   STATUS                2747 non-null   object
#  8   PRODUCTLINE           2747 non-null   object
#  9   MSRP                  2747 non-null   int64
#  10  PRODUCTCODE           2747 non-null   object
#  11  CUSTOMERNAME          2747 non-null   object
#  12  PHONE                 2747 non-null   object
#  13  ADDRESSLINE1          2747 non-null   object
#  14  CITY                  2747 non-null   object
# ...

# %% [markdown]
# - HERE WE ARE SEEING ALL THE NECESSARY INFORMATION ABOUT OUR DATA SET
# - HERE WE CAN EXACTLY SEE ALL THE FEATURES OF THE DATA SET
# - WE CAN SEE WHICH OF THE FEATURES ARE INTEGER TYPE AND WHICH ARE OBJECT TYPE

# %%
sns.histplot(x=df['PRICEEACH'],kde=False,
             bins=8,color='blue',
             )
# Out:
# <Axes: xlabel='PRICEEACH', ylabel='Count'>

# %% [markdown]
# - FROM THE ABOVE HISTOGRAM WE CAN SEE THE DISTRIBUTION OF PRICEEACH ON X-AXIS AND COUNT ON Y-AXIS
# - WE CAN SEE THAT THE ITEMS HAVING PRICE RANGE BETWEEN  55-80 ARE THE HIGHEST IN THE DATA SET
# - WE CAN ALSO SEE THAT THE ITEMS HAVING THE PRICE OF 200-250 ARE THE LOWEST IN THE DATA SET

# %%
sns.relplot(data=df, x="ORDERNUMBER",y="DAYS_SINCE_LASTORDER",kind="line")

# %% [markdown]
# - IN THE ABOVE LINEGRAPH WE CAN SEE THE DISTRIBUTION OF ORDERNUMBER ON X-AXIS AND DAYS SINCE LAAST ORDERD IN Y-AXIS

# %%
import seaborn as sns
sns.barplot(x = 'STATUS',y='DAYS_SINCE_LASTORDER',data = df)
# Out:
# <Axes: xlabel='STATUS', ylabel='DAYS_SINCE_LASTORDER'>

# %% [markdown]
# - HERE WE CAN SEE A BARGRAPH PLOTTER BETWEEN STATUS AT X-AXIS AND DAYS SINCE LAST ORDERED AT Y-AXIS

# %%
sns.histplot(y=df['PRODUCTLINE'],kde=False,
             bins=6,color='blue',
             )
# Out:
# <Axes: xlabel='Count', ylabel='PRODUCTLINE'>

# %% [markdown]
# - IN THE ABOVE HISTOGRAM WE CAN SEE THE DISTRIBUTION OF COUNT ON X-AXIS AND PRODUCTLINE IN Y-AXIS
# - WE CAN SE THAT CLASSIC CARS ARE THE MOST ORDERED ITEM OUT OF THEM ALL
# - WE CAN ALSO SEE THAT TRAINS ARE THE LEAST ORDERED ITEM OUT OF THEM ALL

# %%
sns.scatterplot(y=df['PRODUCTLINE'],x=df['MSRP'])
# Out:
# <Axes: xlabel='MSRP', ylabel='PRODUCTLINE'>

# %% [markdown]
# - HERE WE CAN SEE A SCATTERPLOT BETWEEN MSRP AND PRODUCTLINE
# - AS THE MSPR GOES ON INCREASING THE NUMBER OF ITEMS ARE DECREASED
# - WE CAN SEE THAT MOST OF THE ITEMS ARE AT THE 75-125 MSRP

# %%
corrmat=df.corr()
f,ax=plt.subplots(figsize=(16,12))
sns.heatmap(corrmat,vmax=.8,square=True)
# Out:
# C:\Users\proki\AppData\Local\Temp\ipykernel_12668\1279110003.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corrmat=df.corr()
# <Axes: >

# %% [markdown]
# -this is the heat map of my data set

# %%
sns.boxplot(data=df,x="ORDERLINENUMBER")
# Out:
# <Axes: xlabel='ORDERLINENUMBER'>

# %% [markdown]
# - WE CAN SEE A BOXPLOT OF ORDERLINENUMBER ABOVE
# - WE CAN SEE THAT THE BOX PLOT IS OF NORMAL DISTRIBUTION
# - THE BOX PLOT IS DISPERSED FORM ABOUT 3.0 TO 9.0
# - WE CANOT FIND ANY OUTLIERS IN THE ABOVE BOXPLOT

# %%
sns.histplot(y=df['COUNTRY'],kde=False,
             bins=6,color='blue',
             )
# Out:
# <Axes: xlabel='Count', ylabel='COUNTRY'>

# %% [markdown]
# - ABOVE WE CAN SEE THE GRAPH OF COUNTRY Vs COUNT
# - WE CAN SEE THAT THE COUNTRY THAT ORDERS THE MOST ITEMS IS USA
# - WE CAN ALSO SEE THAT THE COUNTRY THAT ORDERS THE LEAST ITEMS IS IRELAND

# %%
import seaborn as sns
sns.histplot(x='DEALSIZE',data = df)
# Out:
# <Axes: xlabel='DEALSIZE', ylabel='Count'>

# %% [markdown]
# - ABOVE WE CAN SEE THE GRAPH OF DEALSIZE IN X-AXIS AND COUNT ON Y-AXIS
# - WE CAN SEE THAT MOST OF THE DEALS ARE OF MEDIUM SIZE AND ONLY A FEW DEALS ARE OF LARGE SIZE
# - WE CAN ALSO SEE THAT THE NUMBER OF SMALL DEALSIZE AND MEDIUM DEALSIZE ARE NEARLY EQUAL

# %% [markdown]
# # DATA SET ANALYSIS

# %% [markdown]
# - The data is loaded from a CSV file named 'Auto Sales data.csv' into a Pandas DataFrame (df).
# - The first 10 and last 10 rows of the DataFrame are displayed using df.head(10) and df.tail(10).
# - Descriptive statistics of the numeric columns in the DataFrame are shown using df.describe().
# - A histogram of the 'PRICEEACH' column is plotted, showing the distribution of prices.
# - A line plot (sns.relplot) is used to visualize the relationship between 'ORDERNUMBER' and 'DAYS_SINCE_LASTORDER'.
# - A bar plot (sns.barplot) is created to display the average 'DAYS_SINCE_LASTORDER' for each 'STATUS'.
# - A histogram is created to visualize the distribution of 'PRODUCTLINE'.
# - A scatter plot is used to show the relationship between 'MSRP' and 'PRODUCTLINE'.
# - A correlation matrix (sns.heatmap) is plotted to explore the correlations between numeric variables.
# - A box plot is used to visualize the distribution of 'ORDERLINENUMBER'.
# - A histogram is plotted to show the distribution of orders across different countries.
# - A histogram is created to visualize the distribution of 'DEALSIZE'.
